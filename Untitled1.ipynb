# %% [markdown]
# # Regresion lineal: costo d un incidente de seguridad
# En este caso se explican los fundamntos basicos de la regresipn lineal aplicada a un caso sencillo relacionado con la seguridad
#
# ### Enunciado del ejercicio
#
# el ejercicio consiste en predecir el costo de un incidente de seguridad en base al numero de equipos que se ven afectados. el Dataset es generado de manera aleatoria.

# %% [markdown]
# # 1.- Generacion de DataSet

# %%
import numpy as np

x=2 * np.random.rand(100, 1)
y= 4 + 3 * x + np.random.randn(100 ,1)

print("la longitud del DataSet es:", len(x))
# Out:
# la longitud del DataSet es: 100

# %% [markdown]
# # 2.- Visualizacion del Dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(x, y, "b.")
plt.show()

# %%
plt.plot(x, y, "b.")
plt.title("progama chido")
plt.xlabel("Equipos afectados (u/1,000)")
plt.ylabel ("costo del inccidente (u/10,000)")
plt.show()

# %% [markdown]
# #  Modificacion del DataSet

# %%
import pandas as pd

# %%
data = {'No_Equipos_Afectados' : x.flatten(), 'costo': y.flatten()}
df = pd.DataFrame(data)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 data = {'No_Equipos_Afectados' : x.flatten(), 'costo': y.flatten()}
# ----> 2 df = pd.DataFrame(data)
#       3 df.head(10)
#
# File ~/anaconda3/envs/Simulacion/lib/python3.9/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
df['No_Equipos_Afectados'] = df['No_Equipos_Afectados'] * 1000
df['No_Equipos_Afectados'] = df['No_Equipos_Afectados'].astype('int')
# escaladao del costo
df['costo'] = df['costo'] * 1000
df['costo'] = df['costo'].astype('int')
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['no_Equipos_Afectados'] = df['No_Equipos_Afectados'] * 1000
#       2 df['no_Equipos_Afectados'] = df['No_Equipos_Afectados'].astype('int')
#       3 # escaladao del costo
#
# NameError: name 'df' is not defined

# %%
plt.plot(x, y, "b.")
plt.title("progama chido")
plt.xlabel("Equipos afectados")
plt.ylabel ("costo del inccidente")
3plt.show()

# %% [markdown]
# # 4.- Construccion de modelo

# %%
from sklearn.linear_model import LinearRegresion
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sklearn.linear_model import LinearRegresion
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# construccion del modelo y ajuste de la hipótesis
lin_reg = lineaRegresion()
lin_reg.fit(df['No_Equipos_Afectados'].values.reshape(-1, 1), df['Costo'].values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # construccion del modelo y ajuste de la hipótesis
# ----> 2 lin_reg = lineaRegresion()
#       3 lin_reg.fit(df['No_Equipos_Afectados'].values.reshape(-1, 1), df['Costo'].values)
#
# NameError: name 'lineaRegresion' is not defined

# %%
# parametro tetha 0
lin_reg.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # parametro tetha 0
# ----> 2 lin_reg.intercept_
#
# NameError: name 'lin_reg' is not defined

# %%
# parametro tetha 1
lin_reg.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # parametro tetha 1
# ----> 2 lin_reg.coef_
#
# NameError: name 'lin_reg' is not defined

# %%
# prediccion para el valor minimo y maximo del DataSet
x_min_max = np.array([df['No_Equipos_Afectados'].min()], [df['No_Equipos_Afectados'.max()]])
y_train_pred = lin_reg.predict(x_min_max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # prediccion para el valor minimo y maximo del DataSet
# ----> 2 x_min_max = np.array([df['No_Equipos_Afectados'].min()], [df['No_Equipos_Afectados'.max()]])
#       3 y_train_pred = lin_reg.predict(x_min_max)
#
# NameError: name 'df' is not defined

# %%
# representacion grafica de la hipotesis generada.
plt.plot(x_min_max, y_train_pred, "g-")
plt.plot(df['No_Equipos_Afectados'], df['Costo'], "b.")
plt.xlabel("Equipos Afectados")
plt.ylabel("costo del inccidente")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # representacion grafica de la hipotesis generada.
# ----> 2 plt.plot(x_min_max, y_train_pred, "g-")
#       3 plt.plot(df['Numero_Equipos_Afectados'], df['Costo'], "b.")
#       4 plt.xlabel("Equipos Afectados")
#
# NameError: name 'x_min_max' is not defined

# %% [markdown]
# # 5._ prediccion de nuevos ejemplos

# %%
x_new = np.array([[1255]]) # No. de equipos afectados.

# Predicción del costo que tendria el incidente.
Costo = lin_reg.predict(x_new)
print("El costo de incidente seria: ", int(Costo[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 x_new = np.array([[1255]]) # No. de equipos afectados.
#       3 # Predicción del costo que tendria el incidente.
# ----> 4 Costo = lin_reg.predict(x_new)
#       5 print("El costo de incidente seria: ", int(Costo[0]))
#
# NameError: name 'lin_reg' is not defined

# %%
plt.plot(df['No_Equipos_Afectados'], df['costo'], "b.")
plt.plot(x_min_max, y_train_pred, "g-")
plt.plot(x_new, Costo, "rX"
plt.xlabel("Equipos afectados tesji")
plt.ylabel("incidentes")
plt.show()
